# %%
'''
   pandas is an opensource library buillt on top of numpy
   it is used to analyze , clean and manipulate data.

   dataset cleaning , merging and joining .
   easy handling missing missing data(NaN values)
   data visulatization


'''
# Out:
# '\n   pandas is an opensource library buillt on top of numpy \n   it is used to analyze , clean and manipulate data.\n\n   dataset cleaning , merging and joining .\n   easy handling missing missing data(NaN values)\n   data visulatization\n\n\n'

# %%
import pandas as pd
# !pip install pandas  , python -m pip install pandas

# %%
'''
   pandas provide 2 data structures  1) Series - 1Dim     2)DataFrame  -2 dim

'''
# Out:
# '\n   pandas provide 2 data structures  1) Series - 1Dim     2)DataFrame  -2 dim\n\n'

# %%
# create series
series1 =pd.Series([10,20,30])
print(series1)
print(type(series1))
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
series1.ndim
# Out:
# 1

# %%
series2=pd.Series([10,20,30],index=['BMW','Audi','Tata']) # no of index/labels should be same as no of item
series2
# Out:
# BMW     10
# Audi    20
# Tata    30
# dtype: int64

# %%
series2=pd.Series([10,'Hunter',30],index=['BMW','Info','Tata']) # no of index/labels should be same as no of item
series2
# Out:
# BMW         10
# Info    Hunter
# Tata        30
# dtype: object

# %%
series3=pd.Series({'A':10,'B':20,'C':30})
series3
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %%
series4=pd.Series({'A':10,'B':20,'C':30},index=[101,102,103])
series4
# Out:
# 101   NaN
# 102   NaN
# 103   NaN
# dtype: float64

# %%
# access values in a series
# if labelling is string or alpha numric we can acess values by labels as well be indexing  seriesname[label/index]
# if index or label is not found it will raise key error
#if labelling is int or default than we can access value only by using labels

# %%
label=input('enter label to access value')
print('value for given label is',series3[label])
# Out:
# enter label to access valueC
# value for given label is 30

# %%
index=int(input('enter label to access value'))
print('value for given label is',series3[index])
# Out:
# enter label to access value2
# value for given label is 30

# %%
series5=pd.Series([10,20,30],index=[111,222,333]) # no of index/labels should be same as no of item
series5
# Out:
# 111    10
# 222    20
# 333    30
# dtype: int64

# %%
label=int(input('enter label to access value'))
print('value for given label is',series5[label])
# Out:
# enter label to access value111
# value for given label is 10

# %%
series5
# Out:
# 111    10
# 222    20
# 333    30
# dtype: int64

# %%
series5[111]=999  # to update or add new  value  to a series seriesname[index/label]=value
series5
# Out:
# 111    999
# 222     20
# 333     30
# dtype: int64

# %%
series5[405]=777
series5
# Out:
# 111    999
# 222     20
# 333     30
# 405    777
# dtype: int64

# %%
#  2 Dataframe - 2 dim data

# %%
df1=pd.DataFrame([[10,20,30],[40,50,60],[70,80,90]])
df1
# Out:
#     0   1   2
# 0  10  20  30
# 1  40  50  60
# 2  70  80  90

# %%
df1=pd.DataFrame([[10,20,30],[40,50,60],[70,80,90]],index=['BMW','Audi','Tata'])
df1
# Out:
#        0   1   2
# BMW   10  20  30
# Audi  40  50  60
# Tata  70  80  90

# %%
df1=pd.DataFrame([[10,20,30],[40,50,60],[70,80,90]],index=['BMW','Audi','Tata'],columns=[2022,2023,2024])
df1
# Out:
#       2022  2023  2024
# BMW     10    20    30
# Audi    40    50    60
# Tata    70    80    90

# %%
df2=pd.DataFrame({'College':[200,300,400],'College2':[400,500,600]}) # keys becomes column labels
df2
# Out:
#    College  College2
# 0      200       400
# 1      300       500
# 2      400       600

# %%
df2=pd.DataFrame({'College':[200,300,400],'College2':[400,500,600]},index=['cs','it','me']) # keys becomes column labels
df2
# Out:
#     College  College2
# cs      200       400
# it      300       500
# me      400       600

# %%
# access  column data from dataframe  dataframe[columnname] , dataframe.columnname
df2.College2
# Out:
# cs    400
# it    500
# me    600
# Name: College2, dtype: int64

# %%
df2['College2']
# Out:
# cs    400
# it    500
# me    600
# Name: College2, dtype: int64

# %%
# add new column to dataframe dataframe[newcolumname]=[values]
df2['College3']=[30,40,50]
df2
# Out:
#     College  College2  College3
# cs      200       400        30
# it      300       500        40
# me      400       600        50

# %%
# read csv
df_pokemon=pd.read_csv('/content/pokemon.csv')
df_pokemon
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
df_pokemon.type1
# Out:
# 0        grass
# 1        grass
# 2        grass
# 3         fire
# 4         fire
#         ...
# 796      steel
# 797      grass
# 798       dark
# 799    psychic
# 800      steel
# Name: type1, Length: 801, dtype: object

# %%
print(' No  of Different types of pokemon',df_pokemon['type1'].nunique())
print('Different types of pokemon',df_pokemon['type1'].unique())
# Out:
#  No  of Different types of pokemon 18
# Different types of pokemon ['grass' 'fire' 'water' 'bug' 'normal' 'poison' 'electric' 'ground'
#  'fairy' 'fighting' 'psychic' 'rock' 'ghost' 'ice' 'dragon' 'dark' 'steel'
#  'flying']

# %%
#check nan values
df_pokemon.isna().sum()
# Out:
# abilities              0
# against_bug            0
# against_dark           0
# against_dragon         0
# against_electric       0
# against_fairy          0
# against_fight          0
# against_fire           0
# against_flying         0
# against_ghost          0
# against_grass          0
# against_ground         0
# against_ice            0
# against_normal         0
# against_poison         0
# against_psychic        0
# against_rock           0
# against_steel          0
# against_water          0
# attack                 0
# base_egg_steps         0
# base_happiness         0
# base_total             0
# capture_rate           0
# classfication          0
# defense                0
# experience_growth      0
# height_m              20
# hp                     0
# japanese_name          0
# name                   0
# percentage_male       98
# pokedex_number         0
# sp_attack              0
# sp_defense             0
# speed                  0
# type1                  0
# ...

# %%
df_pokemon['type2'].isna().sum()  # nan values in type2 column
# Out:
# 384

# %%
df_pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
# head() shows top 5 values  by default we can change
df_pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df_pokemon['name'].head(10)
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# 5     Charizard
# 6      Squirtle
# 7     Wartortle
# 8     Blastoise
# 9      Caterpie
# Name: name, dtype: object

# %%
df_pokemon.tail() # tails() shows last rows of dataframe by default 5
# Out:
#            abilities  against_bug  against_dark  against_dragon  \
# 796  ['Beast Boost']         0.25           1.0             0.5
# 797  ['Beast Boost']         1.00           1.0             0.5
# 798  ['Beast Boost']         2.00           0.5             2.0
# 799  ['Prism Armor']         2.00           2.0             1.0
# 800   ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 796               2.0            0.5            1.0           2.0
# 797               0.5            0.5            2.0           4.0
# 798               0.5            4.0            2.0           0.5
# 799               1.0            1.0            0.5           1.0
# 800               1.0            0.5            1.0           2.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 796             0.5            1.0  ...              NaN             797
# ...

# %%
df_pokemon.tail(10)
# Out:
#              abilities  against_bug  against_dark  against_dragon  \
# 791  ['Shadow Shield']         1.00           4.0             1.0
# 792    ['Beast Boost']         0.50           1.0             1.0
# 793    ['Beast Boost']         0.50           0.5             1.0
# 794    ['Beast Boost']         0.50           0.5             1.0
# 795    ['Beast Boost']         1.00           1.0             1.0
# 796    ['Beast Boost']         0.25           1.0             0.5
# 797    ['Beast Boost']         1.00           1.0             0.5
# 798    ['Beast Boost']         2.00           0.5             2.0
# 799    ['Prism Armor']         2.00           2.0             1.0
# 800     ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 791               1.0            1.0            0.0           1.0
# 792               1.0            0.5            1.0           0.5
# ...
